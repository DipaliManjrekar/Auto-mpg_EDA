# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np 
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
import pandas as pd
df= pd.read_fwf(r"C:\Users\Dipali\Downloads\auto+mpg\auto-mpg.data")

# %%
pd
# Out:
# <module 'pandas' from 'C:\\Users\\Dipali\\AppData\\Roaming\\Python\\Python310\\site-packages\\pandas\\__init__.py'>

# %%
df
# Out:
#      18.0  8  307.0  130.0   3504.  12.0  70  1 "chevrolet chevelle malibu"
# 0    15.0  8  350.0  165.0  3693.0  11.5  70  1         "buick skylark 320"
# 1    18.0  8  318.0  150.0  3436.0  11.0  70  1        "plymouth satellite"
# 2    16.0  8  304.0  150.0  3433.0  12.0  70  1             "amc rebel sst"
# 3    17.0  8  302.0  140.0  3449.0  10.5  70  1               "ford torino"
# 4    15.0  8  429.0  198.0  4341.0  10.0  70  1          "ford galaxie 500"
# ..    ... ..    ...    ...     ...   ...  .. ..                         ...
# 392  27.0  4  140.0  86.00  2790.0  15.6  82  1           "ford mustang gl"
# 393  44.0  4   97.0  52.00  2130.0  24.6  82  2                 "vw pickup"
# 394  32.0  4  135.0  84.00  2295.0  11.6  82  1             "dodge rampage"
# 395  28.0  4  120.0  79.00  2625.0  18.6  82  1               "ford ranger"
# 396  31.0  4  119.0  82.00  2720.0  19.4  82  1                "chevy s-10"
#
# [397 rows x 9 columns]

# %%
df.columns = ['mpg',           
     'cylinders',     
     'displacement', 
     'horsepower',   
     'weight',       
     'acceleration', 
     'model year',    
     'origin',       
     'car name'  ] 
print(df)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    15.0          8         350.0      165.0  3693.0          11.5
# 1    18.0          8         318.0      150.0  3436.0          11.0
# 2    16.0          8         304.0      150.0  3433.0          12.0
# 3    17.0          8         302.0      140.0  3449.0          10.5
# 4    15.0          8         429.0      198.0  4341.0          10.0
# ..    ...        ...           ...        ...     ...           ...
# 392  27.0          4         140.0      86.00  2790.0          15.6
# 393  44.0          4          97.0      52.00  2130.0          24.6
# 394  32.0          4         135.0      84.00  2295.0          11.6
# 395  28.0          4         120.0      79.00  2625.0          18.6
# 396  31.0          4         119.0      82.00  2720.0          19.4
#
#      model year  origin              car name
# 0            70       1   "buick skylark 320"
# 1            70       1  "plymouth satellite"
# ...

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    15.0          8         350.0      165.0  3693.0          11.5
# 1    18.0          8         318.0      150.0  3436.0          11.0
# 2    16.0          8         304.0      150.0  3433.0          12.0
# 3    17.0          8         302.0      140.0  3449.0          10.5
# 4    15.0          8         429.0      198.0  4341.0          10.0
# ..    ...        ...           ...        ...     ...           ...
# 392  27.0          4         140.0      86.00  2790.0          15.6
# 393  44.0          4          97.0      52.00  2130.0          24.6
# 394  32.0          4         135.0      84.00  2295.0          11.6
# 395  28.0          4         120.0      79.00  2625.0          18.6
# 396  31.0          4         119.0      82.00  2720.0          19.4
#
#      model year  origin              car name
# 0            70       1   "buick skylark 320"
# 1            70       1  "plymouth satellite"
# ...

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  15.0          8         350.0      165.0  3693.0          11.5          70
# 1  18.0          8         318.0      150.0  3436.0          11.0          70
# 2  16.0          8         304.0      150.0  3433.0          12.0          70
# 3  17.0          8         302.0      140.0  3449.0          10.5          70
# 4  15.0          8         429.0      198.0  4341.0          10.0          70
#
#    origin              car name
# 0       1   "buick skylark 320"
# 1       1  "plymouth satellite"
# 2       1       "amc rebel sst"
# 3       1         "ford torino"
# 4       1    "ford galaxie 500"

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 392  27.0          4         140.0      86.00  2790.0          15.6
# 393  44.0          4          97.0      52.00  2130.0          24.6
# 394  32.0          4         135.0      84.00  2295.0          11.6
# 395  28.0          4         120.0      79.00  2625.0          18.6
# 396  31.0          4         119.0      82.00  2720.0          19.4
#
#      model year  origin           car name
# 392          82       1  "ford mustang gl"
# 393          82       2        "vw pickup"
# 394          82       1    "dodge rampage"
# 395          82       1      "ford ranger"
# 396          82       1       "chevy s-10"

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 392    False
# 393    False
# 394    False
# 395    False
# 396    False
# Length: 397, dtype: bool

# %%
df.shape
# Out:
# (397, 9)

# %%
df['acceleration']=df['acceleration'].astype(int)

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    15.0          8         350.0      165.0  3693.0            11
# 1    18.0          8         318.0      150.0  3436.0            11
# 2    16.0          8         304.0      150.0  3433.0            12
# 3    17.0          8         302.0      140.0  3449.0            10
# 4    15.0          8         429.0      198.0  4341.0            10
# ..    ...        ...           ...        ...     ...           ...
# 392  27.0          4         140.0      86.00  2790.0            15
# 393  44.0          4          97.0      52.00  2130.0            24
# 394  32.0          4         135.0      84.00  2295.0            11
# 395  28.0          4         120.0      79.00  2625.0            18
# 396  31.0          4         119.0      82.00  2720.0            19
#
#      model year  origin              car name
# 0            70       1   "buick skylark 320"
# 1            70       1  "plymouth satellite"
# ...

# %%
df['mpg']=df['mpg'].astype(int)

# %%
df.dtypes
# Out:
# mpg               int32
# cylinders         int64
# displacement    float64
# horsepower       object
# weight          float64
# acceleration      int32
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
df = df.replace('?',np.nan)
df.head()
# Out:
#    mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0   15          8         350.0      165.0  3693.0            11          70
# 1   18          8         318.0      150.0  3436.0            11          70
# 2   16          8         304.0      150.0  3433.0            12          70
# 3   17          8         302.0      140.0  3449.0            10          70
# 4   15          8         429.0      198.0  4341.0            10          70
#
#    origin              car name
# 0       1   "buick skylark 320"
# 1       1  "plymouth satellite"
# 2       1       "amc rebel sst"
# 3       1         "ford torino"
# 4       1    "ford galaxie 500"

# %%
df
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0     15          8         350.0      165.0  3693.0            11
# 1     18          8         318.0      150.0  3436.0            11
# 2     16          8         304.0      150.0  3433.0            12
# 3     17          8         302.0      140.0  3449.0            10
# 4     15          8         429.0      198.0  4341.0            10
# ..   ...        ...           ...        ...     ...           ...
# 392   27          4         140.0      86.00  2790.0            15
# 393   44          4          97.0      52.00  2130.0            24
# 394   32          4         135.0      84.00  2295.0            11
# 395   28          4         120.0      79.00  2625.0            18
# 396   31          4         119.0      82.00  2720.0            19
#
#      model year  origin              car name
# 0            70       1   "buick skylark 320"
# 1            70       1  "plymouth satellite"
# ...

# %%
df.mpg.unique()
# Out:
# array([15, 18, 16, 17, 14, 24, 22, 21, 27, 26, 25, 10, 11,  9, 28, 19, 12,
#        13, 23, 30, 31, 35, 20, 29, 32, 33, 36, 43, 39, 34, 37, 41, 38, 46,
#        40, 44])

# %%
df.cylinders.unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
df.displacement.unique()
# Out:
# array([350. , 318. , 304. , 302. , 429. , 454. , 440. , 455. , 390. ,
#        383. , 340. , 400. , 113. , 198. , 199. , 200. ,  97. , 110. ,
#        107. , 104. , 121. , 360. , 307. , 140. ,  98. , 232. , 225. ,
#        250. , 351. , 258. , 122. , 116. ,  79. ,  88. ,  71. ,  72. ,
#         91. ,  97.5,  70. , 120. ,  96. , 108. , 155. ,  68. , 114. ,
#        156. ,  76. ,  83. ,  90. , 231. , 262. , 134. , 119. , 171. ,
#        115. , 101. , 305. ,  85. , 130. , 168. , 111. , 260. , 151. ,
#        146. ,  80. ,  78. , 105. , 131. , 163. ,  89. , 267. ,  86. ,
#        183. , 141. , 173. , 135. ,  81. , 100. , 145. , 112. , 181. ,
#        144. ])

# %%
df['model year'].unique()
# Out:
# array([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], dtype=int64)

# %%
df['mpg']=df['mpg'].astype(int)
df['cylinders']=df['cylinders'].astype(int)
df['displacement']=df['displacement'].astype(int)

df['weight']=df['weight'].astype(int)
df['acceleration']=df['acceleration'].astype(int)
df['model year']=df['model year'].astype(int)
df['origin']=df['origin'].astype(int)

# %%
df.dtypes
# Out:
# mpg              int32
# cylinders        int32
# displacement     int32
# horsepower      object
# weight           int32
# acceleration     int32
# model year       int32
# origin           int32
# car name        object
# dtype: object

# %%
df['car name'].unique()
# Out:
# array(['"buick skylark 320"', '"plymouth satellite"', '"amc rebel sst"',
#        '"ford torino"', '"ford galaxie 500"', '"chevrolet impala"',
#        '"plymouth fury iii"', '"pontiac catalina"',
#        '"amc ambassador dpl"', '"dodge challenger se"',
#        '"plymouth \'cuda 340"', '"chevrolet monte carlo"',
#        '"buick estate wagon (sw)"', '"toyota corona mark ii"',
#        '"plymouth duster"', '"amc hornet"', '"ford maverick"',
#        '"datsun pl510"', '"volkswagen 1131 deluxe sedan"',
#        '"peugeot 504"', '"audi 100 ls"', '"saab 99e"', '"bmw 2002"',
#        '"amc gremlin"', '"ford f250"', '"chevy c20"', '"dodge d200"',
#        '"hi 1200d"', '"chevrolet vega 2300"', '"toyota corona"',
#        '"ford pinto"', '"plymouth satellite custom"',
#        '"chevrolet chevelle malibu"', '"ford torino 500"',
#        '"amc matador"', '"pontiac catalina brougham"',
#        '"dodge monaco (sw)"', '"ford country squire (sw)"',
# ...

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0     15          8           350      165.0    3693            11
# 1     18          8           318      150.0    3436            11
# 2     16          8           304      150.0    3433            12
# 3     17          8           302      140.0    3449            10
# 4     15          8           429      198.0    4341            10
# ..   ...        ...           ...        ...     ...           ...
# 392   27          4           140      86.00    2790            15
# 393   44          4            97      52.00    2130            24
# 394   32          4           135      84.00    2295            11
# 395   28          4           120      79.00    2625            18
# 396   31          4           119      82.00    2720            19
#
#      model year  origin              car name
# 0            70       1   "buick skylark 320"
# ...

# %%
df['weight']= df['weight'].astype('int')
df.dtypes
# Out:
# mpg              int32
# cylinders        int32
# displacement     int32
# horsepower      object
# weight           int32
# acceleration     int32
# model year       int32
# origin           int32
# car name        object
# dtype: object

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.iloc[5:11].plot(kind = 'bar', figsize = (10,8))
# Out:
# <Axes: >

# %%
df.iloc[5:11].plot(kind = 'barh', figsize = (10,8))
# Out:
# <Axes: >

# %%
df.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['weight'].plot(kind = 'hist',figsize=(20,10), orientation = 'horizontal')
# Out:
# <Axes: xlabel='Frequency'>

# %%
df.plot(kind = 'box', figsize=(20,10), color = {'boxes' :'b','whiskers' : 'r' })
# Out:
# <Axes: >

# %%
df.plot(kind = 'area', figsize = (20,10), alpha = 0.4, stacked = False)
# Out:
# <Axes: >

# %%
x=df['mpg']
y=df['acceleration']
plt.scatter(x,y)
plt.xlabel('Mpg',fontsize=10)
plt.ylabel('Acceleration',fontsize=10)
# Out:
# Text(0, 0.5, 'Acceleration')

# %%
plt.figure(figsize=(10,6))
sns.boxplot(df['acceleration'],palette='rainbow')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6))
sns.stripplot(y='mpg',hue='acceleration',x='cylinders',data=df)
# Out:
# <Axes: xlabel='cylinders', ylabel='mpg'>

# %%
plt.figure(figsize=(10,6))
sns.violinplot(y='mpg',x='cylinders',data=df)
# Out:
# <Axes: xlabel='cylinders', ylabel='mpg'>

# %%
plt.figure(figsize=(12,8))
sns.pairplot(df)

# %%
plt.figure(figsize=(12,8))
sns.pairplot(data=df,hue='acceleration')

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df,y='model year',x='acceleration')
# Out:
# <Axes: xlabel='acceleration', ylabel='model year'>

# %%
sns.set_style("whitegrid")
sns.countplot(x='cylinders',data=df,palette='magma')
# Out:
# <Axes: xlabel='cylinders', ylabel='count'>

# %%
df['weight'].hist(color='green',bins=40,figsize=(8,6))
# Out:
# <Axes: >

# %% [markdown]
# # Frequently Asked Questions (FAQ)

# %%
acceleration=df[df['acceleration']==df['acceleration'].max()]

cylinders=acceleration['cylinders'].iloc[0]
print(f"The auto of having maximum acceleration is having  :{cylinders}")
# Out:
# The auto of having maximum acceleration is having  :4

# %%
acceleration=df[df['acceleration']==df['acceleration'].min()]

cylinders=acceleration['cylinders'].iloc[0]
print(f"The auto of having minimum acceleration is having  :{cylinders}")
# Out:
# The auto of having minimum acceleration is having  :8

# %%
df.groupby(['acceleration', 'cylinders'])['model year'].max()
# Out:
# acceleration  cylinders
# 8             8            70
# 9             8            73
# 10            8            70
# 11            4            82
#               6            80
#               8            78
# 12            3            80
#               4            81
#               6            81
#               8            78
# 13            3            77
#               4            82
#               6            81
#               8            79
# 14            4            82
#               6            82
#               8            79
# 15            4            82
#               5            78
#               6            81
#               8            79
# 16            4            82
#               6            82
#               8            74
# 17            4            82
#               6            82
#               8            79
# 18            4            82
#               6            80
#               8            70
# ...

# %%
df.groupby(['acceleration', 'cylinders'])['model year'].min()
# Out:
# acceleration  cylinders
# 8             8            70
# 9             8            70
# 10            8            70
# 11            4            82
#               6            79
#               8            70
# 12            3            80
#               4            70
#               6            79
#               8            70
# 13            3            72
#               4            75
#               6            71
#               8            70
# 14            4            70
#               6            71
#               8            70
# 15            4            70
#               5            78
#               6            70
#               8            70
# 16            4            72
#               6            70
#               8            72
# 17            4            70
#               6            74
#               8            79
# 18            4            71
#               6            73
#               8            70
# ...
